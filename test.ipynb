# %%
import pickle

path = "/root/dev/MPMAvatar/data/4D-DRESS/Inner/Take2/Meshes_pkl/atlas-f00021.pkl"
with open(path, 'rb') as f:
    object = pickle.load(f)

# %%
type(object)
object.shape
# Out:
# (1024, 1024, 3)

# %%
path = "/root/dev/MPMAvatar/data/4D-DRESS/Inner/Take2/SMPL/mesh-f00021_smpl.pkl"
with open(path, 'rb') as f:
    object = pickle.load(f)

# %%
object
# Out:
# {'global_orient': array([-0.00968315, -0.3468797 , -0.01895677], dtype=float32),
#  'body_pose': array([ 1.21292751e-02,  1.74915791e-02,  1.41166329e-01,  1.77970640e-02,
#         -3.72231454e-02, -7.58534521e-02, -8.82920995e-03,  5.95718343e-03,
#          3.81950056e-03, -3.16093233e-03,  5.47375344e-03, -1.84119791e-02,
#          1.04073482e-02, -1.93708334e-02, -8.26715026e-03, -1.02125751e-02,
#         -3.55641171e-03,  1.16036190e-02, -1.77957471e-02,  9.97572392e-02,
#          1.51725753e-05, -1.77360382e-02, -1.74000338e-01, -1.52115808e-05,
#          6.99693486e-02,  1.10128606e-02, -1.19549297e-02, -1.60339041e-05,
#          1.64425383e-05, -1.59374977e-05,  1.47883220e-05, -1.62813467e-05,
#         -1.53073579e-05, -1.57324672e-01, -7.38971010e-02, -4.80058342e-02,
#         -5.61766922e-02, -2.13304143e-02, -3.41965735e-01,  2.62789167e-02,
#          7.37708881e-02,  3.70451361e-01,  7.60991797e-02, -1.43255014e-03,
# ...

# %%
for key, value in object.items():
    print(f"{key} shape: {value.shape}")
# Out:
# global_orient shape: (3,)
# body_pose shape: (69,)
# transl shape: (3,)
# betas shape: (10,)
